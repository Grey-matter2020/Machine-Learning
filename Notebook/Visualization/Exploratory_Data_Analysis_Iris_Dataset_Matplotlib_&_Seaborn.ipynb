# %% [markdown]
# <a href="https://colab.research.google.com/github/Grey-matter2020/Machine-Learning/blob/main/Notebook/Visualization/Exploratory_Data_Analysis_Iris_Dataset_Matplotlib_%26_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Plotting for Exploratory data analysis (EDA)

# %% [markdown]
# # (1.1) Basic Terminology

# %% [markdown]
# * What is EDA?
# * Data-point/Observation
# * Data-set
# * Feature/Variable/Input-variable/Independent-varibale
# * Label/Depdendent-variable/Output-varible/Class/Class-label/Response label

# %% [markdown]
# ## Iris Flower dataset

# %% [markdown]
# Toy  Dataset: Iris Dataset: https://en.wikipedia.org/wiki/Iris_flower_data_set
# * A simple dataset to learn the basics.
# * 3 flowers of Iris species. https://en.wikipedia.org/wiki/Iris_flower_data_set
# * Petal and Sepal: http://terpconnect.umd.edu/~petersd/666/html/iris_with_labels.jpg
# *  Objective: Classify a new flower as belonging to one of the 3 classes given the 4 features.
# * Why use petal and sepal dimensions as features?
# * Why do we not use 'color' as a feature? Importance of domain knowledge.

# %%
# Connect to the Google Drive to read the iris.csv file
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Listing down files in the gdrive folder
# !ls gdrive/
# Out:
# MyDrive

# %%
#List the folder in the g drive
# !ls "/content/gdrive/My Drive/"
# Out:
# 'Machine Learning'

# %%
#List the files in the Visualization folder
# !ls "/content/gdrive/My Drive/Machine Learning/Visualization"
# Out:
# 'Exploratory Data Analysis - Haberman Dataset-Matplotlib & Seaborn.ipynb'
# 'Exploratory Data Analysis - Iris Dataset - Matplotlib & Seaborn.ipynb'
#  haberman.csv
#  iris.csv

# %%
#Changing the directory to Visualization
# %cd "/content/gdrive/My Drive/Machine Learning/Visualization"
# Out:
# /content/gdrive/My Drive/Machine Learning/Visualization

# %%
#Understand the present current working directory
# !pwd
# Out:
# /content/gdrive/My Drive/Machine Learning/Visualization

# %%
# Listing down files in the Visualization folder
# !ls
# Out:
# 'Exploratory Data Analysis - Haberman Dataset-Matplotlib & Seaborn.ipynb'
# 'Exploratory Data Analysis - Iris Dataset - Matplotlib & Seaborn.ipynb'
#  haberman.csv
#  iris.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')


'''downlaod iris.csv from https://www.kaggle.com/datasets/arshid/iris-flower-dataset'''
#Load Iris.csv into a pandas dataFrame.
iris = pd.read_csv("iris.csv")

# %%
#Find the number of data in the dataset
iris.shape
# Out:
# (150, 5)

# %%
#(Q) What are the column names in our dataset?
print (iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
#(Q) How many data points for each class are present? 
#(or) How many flowers for each species are present?

iris["species"].value_counts()
# balanced-dataset vs imbalanced datasets
#Iris is a balanced dataset as the number of data points for every class is 50.
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# # (1.2) 2-D Scatter Plot

# %%
#### https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html
    
x = iris['sepal_length']
y = iris['sepal_width']

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %% [markdown]
# What we got here is a Line plot as compared to Scatter plot

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.set_figwidth(4)
fig.set_figheight(6)

# %%
#### https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html
    
x = iris['sepal_length']
y = iris['sepal_width']

fig, ax = plt.subplots()
fig.set_figwidth(4)
fig.set_figheight(4)
ax.plot(x, y)
ax.set_xlabel ='sepal_length'
ax.set_ylabel ='sepal_width'
ax.set_title('Simple plot')
plt.show()

# %% [markdown]
# Height and Width of the plot is changed
# What Happened we didnt get the x and y label?

# %%
#### https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html
    
x = iris['sepal_length']
y = iris['sepal_width']

fig, ax = plt.subplots()
fig.set_figwidth(4)
fig.set_figheight(4)


ax.set_xlabel = ('sepal_length')
ax.set_ylabel = ('sepal_width')
ax.set_title('Simple plot')
ax.plot(x, y)

plt.show()

# %% [markdown]
# Still the labels are missing

# %%
#### https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html
    
x = iris['sepal_length']
y = iris['sepal_width']

fig, ax = plt.subplots()
fig.set_figwidth(4)
fig.set_figheight(4)

ax.plot(x, y)
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
ax.set_title('Simple plot')


plt.show()

# %% [markdown]
# Finally the labels are Up

# %%
plt.subplots(2,2)
plt.show()

# %% [markdown]
# How to make more than 1 plot

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

# %%
#2-D scatter plot:
#ALWAYS understand the axis: labels and scale.

x = iris['sepal_length']
y = iris['sepal_width']
fig, ax = plt.subplots()
ax.scatter(x, y)
plt.show()

#cannot make much sense out it. 
#What if we color the points by thier class-label/flower-type.

# %%
#2-D scatter plot:
#ALWAYS understand the axis: labels and scale.

colors = {'setosa':'tab:blue', 'versicolor':'tab:orange', 'virginica':'tab:green'}
x = iris['sepal_length']
y = iris['sepal_width']
fig, ax = plt.subplots()
ax.scatter(x, y,c=iris['species'].map(colors))
plt.show()

# %% [markdown]
# So many ways of plotting the same visualization

# %%
#2-D scatter plot:
#ALWAYS understand the axis: labels and scale.

iris.plot(kind='scatter', x='sepal_length', y='sepal_width') ;
plt.show()

#cannot make much sense out it. 
#What if we color the points by thier class-label/flower-type.

# %%
#2-D scatter plot:
#ALWAYS understand the axis: labels and scale.

x = iris['sepal_length']
y = iris['sepal_width']
plt.plot(x, y,'o') 
plt.show()

#cannot make much sense out it. 
#What if we color the points by thier class-label/flower-type.

# %%
#2-D scatter plot:
#ALWAYS understand the axis: labels and scale.

x = iris['sepal_length']
y = iris['sepal_width']
plt.scatter(x, y) 
plt.show()

#cannot make much sense out it. 
#What if we color the points by thier class-label/flower-type.

# %%
#2-D scatter plot:
#ALWAYS understand the axis: labels and scale.

x = iris['sepal_length']
y = iris['sepal_width']
plt.plot(x, y) 
plt.show()

#cannot make much sense out it. 
#What if we color the points by thier class-label/flower-type.

# %% [markdown]
# Plotting using Seaborn

# %%
# 2-D Scatter plot with color-coding for each flower type/class.
# Here 'sns' corresponds to seaborn. 
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", height=4) \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend();
plt.show();

# Notice that the blue points can be easily seperated 
# from red and green by drawing a line. 
# But red and green data points cannot be easily seperated.
# Can we draw multiple 2-D scatter plots for each combination of features?
# How many cobinations exist? 4C2 = 6.

# %%
# 2-D Scatter plot with color-coding for each flower type/class.
# Here 'sns' corresponds to seaborn. 
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", height=4) 
plt.show();

# Notice that the blue points can be easily seperated 
# from red and green by drawing a line. 
# But red and green data points cannot be easily seperated.
# Can we draw multiple 2-D scatter plots for each combination of features?
# How many cobinations exist? 4C2 = 6.

# %%
# 2-D Scatter plot with color-coding for each flower type/class.
# Here 'sns' corresponds to seaborn. 
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", height=4) \
   .map(plt.scatter, "sepal_length", "sepal_width") 
plt.show();

# Notice that the blue points can be easily seperated 
# from red and green by drawing a line. 
# But red and green data points cannot be easily seperated.
# Can we draw multiple 2-D scatter plots for each combination of features?
# How many cobinations exist? 4C2 = 6.

# %%
# 2-D Scatter plot with color-coding for each flower type/class.
# Here 'sns' corresponds to seaborn. 
sns.set_style("whitegrid");
sns.FacetGrid(iris, hue="species", height=4) \
   .map(plt.scatter, "sepal_length", "sepal_width") \
   .add_legend();
plt.show();

# Notice that the blue points can be easily seperated 
# from red and green by drawing a line. 
# But red and green data points cannot be easily seperated.
# Can we draw multiple 2-D scatter plots for each combination of features?
# How many cobinations exist? 4C2 = 6.

# %% [markdown]
# How many different syntax did we use for plotting our scatter plot
# * ax.scatter(x, y)
# * iris.plot(kind='scatter', x='sepal_length', y='sepal_width')
# * plt.plot(x, y,'o')
# * plt.scatter(x, y)
# * sns.FacetGrid(iris, hue="species", size=4).map(plt.scatter, "sepal_length", "sepal_width")

# %% [markdown]
# **Observation(s):**
# 1. Using sepal_length and sepal_width features, we can distinguish Setosa flowers from others.
# 2. Seperating Versicolor from Viginica is much harder as they have considerable overlap.

# %% [markdown]
# ## 3D Scatter plot
#
# https://plot.ly/pandas/3d-scatter-plots/
#
# Needs a lot to mouse interaction to interpret data.
#
# What about 4-D, 5-D or n-D scatter plot?

# %% [markdown]
# #  (1.3) Pair-plot

# %%
# pairwise scatter plot: Pair-Plot
# Dis-advantages: 
##Cannot be used when number of features are high.
##Cannot visualize higher dimensional patterns in 3-D and 4-D. 
#Only possible to view 2D patterns.
plt.close();
sns.set_style("whitegrid");
sns.pairplot(iris, hue="species", height=3);
plt.show()
# NOTE: the diagnol elements are PDFs for each feature. PDFs are expalined below.

# %% [markdown]
# **Observations**
# 1. petal_length and petal_width are the most useful features to identify various flower types.
# 2. While Setosa can be easily identified (linearly seperable), Virnica and Versicolor have some overlap (almost linearly seperable).
# 3. We can find "lines" and "if-else" conditions to build a simple model to classify the flower types.

# %% [markdown]
# # (1.4) Histogram, PDF, CDF

# %%
# What about 1-D scatter plot using just one feature?
#1-D scatter plot of petal-length
import numpy as np
iris_setosa = iris.loc[iris["species"] == "setosa"];
iris_virginica = iris.loc[iris["species"] == "virginica"];
iris_versicolor = iris.loc[iris["species"] == "versicolor"];
#print(iris_setosa["petal_length"])
plt.plot(iris_setosa["petal_length"], np.zeros_like(iris_setosa['petal_length']), 'o')
plt.plot(iris_versicolor["petal_length"], np.zeros_like(iris_versicolor['petal_length']), 'o')
plt.plot(iris_virginica["petal_length"], np.zeros_like(iris_virginica['petal_length']), 'o')

plt.show()
#Disadvantages of 1-D scatter plot: Very hard to make sense as points 
#are overlapping a lot.
#Are there better ways of visualizing 1-D scatter plots?

# %%
sns.FacetGrid(iris, hue="species", height=5) \
   .map(sns.distplot, "petal_length") \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(iris, hue="species", height=5) \
   .map(sns.distplot, "petal_width") \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(iris, hue="species", height=5) \
   .map(sns.distplot, "sepal_length") \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(iris, hue="species", height=5) \
   .map(sns.distplot, "sepal_width") \
   .add_legend();
plt.show();

# %%
sns.FacetGrid(iris, hue="species", height=5) \
   .map(sns.histplot, "sepal_width") \
   .add_legend();
plt.show();

# %%
# Histograms and Probability Density Functions (PDF) using KDE
sns.FacetGrid(iris, hue="species", height=5) \
   .map(sns.kdeplot, "sepal_width") \
   .add_legend();
plt.show();

# %%
# How to compute PDFs using counts/frequencies of data points in each window.

# %%
# How window width effects the PDF plot.- A smaller window width makes the plot less smooth whereas 
# bigger window size makes the plot too smooth

sns.kdeplot(data=iris['sepal_width'],bw_adjust=.2)
sns.kdeplot(data=iris['sepal_width'])
sns.kdeplot(data=iris['sepal_width'],bw_adjust=5)

# %%
sns.kdeplot(data=iris['sepal_width'],bw_adjust=0.5)

# %% [markdown]
# Q. Interpreting a PDF:
# * It represents the distribution of data points and the under under the curve is always 1

# %% [markdown]
# Q. Why is it called a density plot?
# *  Because it defines the probability density over some interval
#
# Q. Why is it called a probability plot?
#
# * Because the are under the curve is 1. The area under the curve between two data point is the probability of the value lying between the two data points

# %% [markdown]
# Q. For each value of petal_length, what does the value on y-axis mean?
# * For a single point of petal_length, the corresponding point on y axis means nothing. However, the y axis for 2 different values of petal_legth can be used to infer its likelihood of happening.

# %%
# Notice that we can write a simple if..else condition as if(petal_length) < 2.5 then flower type is setosa.
# Using just one feature, we can build a simple "model" suing if..else... statements.

# %% [markdown]
# Q. Disadv of PDF: Can we say what percentage of versicolor points have a petal_length of less than 5?
# *  Approximately but not exactly
#
# Q. Do some of these plots look like a bell-curve you studied in under-grad?
# *  Yes
#
# Q. Gaussian/Normal distribution.
#
# Q. What is "normal" about normal distribution?
# *  Early statisticians noticed the same shape coming up over and over again in different distributions—so they named it the normal distribution

# %%
# Need for Cumulative Distribution Function (CDF)
# We can visually see what percentage of versicolor flowers have a 
# petal_length of less than 1.6?
# How to construct a CDF?
# How to read a CDF?

#Plot CDF of petal_length

sns.kdeplot(iris['petal_length'])
sns.kdeplot(iris['petal_length'],cumulative= True)

# %%
sns.kdeplot(iris['petal_width'])
sns.kdeplot(iris['petal_width'],cumulative= True)

# %%
sns.kdeplot(iris['sepal_length'])
sns.kdeplot(iris['sepal_length'],cumulative= True)

# %%
sns.kdeplot(iris['sepal_width'])
sns.kdeplot(iris['sepal_width'],cumulative= True)

# %% [markdown]
# # (1.5) Mean, Variance and Std-dev

# %%
#Mean, Variance, Std-deviation,  
print("Means:")
print(np.mean(iris_setosa["petal_length"]))
#Mean with an outlier.
print(np.mean(np.append(iris_setosa["petal_length"],50)));
print(np.mean(iris_virginica["petal_length"]))
print(np.mean(iris_versicolor["petal_length"]))

print("\nStd-dev:");
print(np.std(iris_setosa["petal_length"]))
print(np.std(iris_virginica["petal_length"]))
print(np.std(iris_versicolor["petal_length"]))
# Out:
# Means:
# 1.464
# 2.4156862745098038
# 5.5520000000000005
# 4.26
#
# Std-dev:
# 0.17176728442867112
# 0.546347874526844
# 0.4651881339845203

# %% [markdown]
# # (1.6) Median, Percentile, Quantile, IQR, MAD

# %%
np.arange(0, 100, 25)
# Out:
# array([ 0, 25, 50, 75])

# %%
#Median, Quantiles, Percentiles, IQR.
print("\nMedians:")
print(np.median(iris_setosa["petal_length"]))
#Median with an outlier
print(np.median(np.append(iris_setosa["petal_length"],50)));
print(np.median(iris_virginica["petal_length"]))
print(np.median(iris_versicolor["petal_length"]))


print("\n90th Percentiles:")
print(np.percentile(iris_setosa["petal_length"],90))
print(np.percentile(iris_virginica["petal_length"],90))
print(np.percentile(iris_versicolor["petal_length"], 90))

print("\nQuantiles:")
print(np.percentile(iris_setosa["petal_length"],np.arange(0, 100, 25)))
print(np.percentile(iris_virginica["petal_length"],np.arange(0, 100, 25)))
print(np.percentile(iris_versicolor["petal_length"], np.arange(0, 100, 25)))


from statsmodels import robust
print ("\nMedian Absolute Deviation")
print(robust.mad(iris_setosa["petal_length"]))
print(robust.mad(iris_virginica["petal_length"]))
print(robust.mad(iris_versicolor["petal_length"]))
# Out:
# Medians:
# 1.5
# 1.5
# 5.55
# 4.35
#
# 90th Percentiles:
# 1.7
# 6.31
# 4.8
#
# Quantiles:
# [1.    1.4   1.5   1.575]
# [4.5   5.1   5.55  5.875]
# [3.   4.   4.35 4.6 ]
#
# Median Absolute Deviation
# 0.14826022185056031
# 0.6671709983275211
# 0.5189107764769602

# %% [markdown]
# # (1.7) Box plot and Whiskers

# %%
#Box-plot with whiskers: another method of visualizing the  1-D scatter plot more intuitivey.
# The Concept of median, percentile, quantile.
# How to draw the box in the box-plot?
# How to draw whiskers: [no standard way] Could use min and max or use other complex statistical techniques.
# IQR like idea.

#NOTE: IN the plot below, a technique call inter-quartile range is used in plotting the whiskers. 
#Whiskers in the plot below donot correposnd to the min and max values.

#Box-plot can be visualized as a PDF on the side-ways.

sns.boxplot(x='species',y='petal_length', data=iris)
plt.show()

# %% [markdown]
# # (1.8) Violin plots

# %%
# A violin plot combines the benefits of the previous two plots 
#and simplifies them

# Denser regions of the data are fatter, and sparser ones thinner 
#in a violin plot

sns.violinplot(x="species", y="petal_length", data=iris, size=8)
plt.show()

# %% [markdown]
# # (1.9) Multivariate probability density, contour plot.

# %%
#2D Density plot, contors-plot
sns.jointplot(x="petal_length", y="petal_width", data=iris_setosa, kind='hex');
plt.show();

# %%
#2D Density plot, contors-plot
sns.jointplot(x="petal_length", y="petal_width", data=iris_setosa, kind="kde");
plt.show();

# %%
# https://en.wikipedia.org/wiki/Multivariate_normal_distribution
